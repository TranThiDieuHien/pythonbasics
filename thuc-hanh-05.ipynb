# %% [markdown]
# THỰC HÀNH TRỰC QUAN HÓA DỮ LIỆU NÂNG CAO

# %%
import seaborn as sns
import pandas as pd 

microbiome = pd.read_csv("C:\\Users\\DELL\\Documents\\microbiome.csv")
sns.pairplot(data = microbiome, diag_kind="hist")

# %%
baseball = pd.read_csv("C:\\Users\\DELL\\Documents\\baseball.csv")
B = sns.pairplot(data = baseball, kind="hist")
